# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Housing.csv')

df
# Out:
#         price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0    13300000  7420         4  ...        2       yes        furnished
# 1    12250000  8960         4  ...        3        no        furnished
# 2    12250000  9960         3  ...        2       yes   semi-furnished
# 3    12215000  7500         4  ...        3       yes        furnished
# 4    11410000  7420         4  ...        2        no        furnished
# ..        ...   ...       ...  ...      ...       ...              ...
# 540   1820000  3000         2  ...        2        no      unfurnished
# 541   1767150  2400         3  ...        0        no   semi-furnished
# 542   1750000  3620         2  ...        0        no      unfurnished
# 543   1750000  2910         3  ...        0        no        furnished
# 544   1750000  3850         3  ...        0        no      unfurnished
#
# [545 rows x 13 columns]

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
df.head(5)
# Out:
#       price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0  13300000  7420         4  ...        2       yes        furnished
# 1  12250000  8960         4  ...        3        no        furnished
# 2  12250000  9960         3  ...        2       yes   semi-furnished
# 3  12215000  7500         4  ...        3       yes        furnished
# 4  11410000  7420         4  ...        2        no        furnished
#
# [5 rows x 13 columns]

# %%
df.tail(5)
# Out:
#        price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 540  1820000  3000         2  ...        2        no      unfurnished
# 541  1767150  2400         3  ...        0        no   semi-furnished
# 542  1750000  3620         2  ...        0        no      unfurnished
# 543  1750000  2910         3  ...        0        no        furnished
# 544  1750000  3850         3  ...        0        no      unfurnished
#
# [5 rows x 13 columns]

# %%
df.to_numpy()
# Out:
# array([[13300000, 7420, 4, ..., 2, 'yes', 'furnished'],
#        [12250000, 8960, 4, ..., 3, 'no', 'furnished'],
#        [12250000, 9960, 3, ..., 2, 'yes', 'semi-furnished'],
#        ...,
#        [1750000, 3620, 2, ..., 0, 'no', 'unfurnished'],
#        [1750000, 2910, 3, ..., 0, 'no', 'furnished'],
#        [1750000, 3850, 3, ..., 0, 'no', 'unfurnished']], dtype=object)

# %%
df.describe()
# Out:
#               price          area  ...     stories     parking
# count  5.450000e+02    545.000000  ...  545.000000  545.000000
# mean   4.766729e+06   5150.541284  ...    1.805505    0.693578
# std    1.870440e+06   2170.141023  ...    0.867492    0.861586
# min    1.750000e+06   1650.000000  ...    1.000000    0.000000
# 25%    3.430000e+06   3600.000000  ...    1.000000    0.000000
# 50%    4.340000e+06   4600.000000  ...    2.000000    0.000000
# 75%    5.740000e+06   6360.000000  ...    2.000000    1.000000
# max    1.330000e+07  16200.000000  ...    4.000000    3.000000
#
# [8 rows x 6 columns]

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#     airconditioning  area basement  ...  prefarea     price stories
# 0               yes  7420       no  ...       yes  13300000       3
# 1               yes  8960       no  ...        no  12250000       4
# 2                no  9960      yes  ...       yes  12250000       2
# 3               yes  7500      yes  ...       yes  12215000       2
# 4               yes  7420      yes  ...        no  11410000       2
# ..              ...   ...      ...  ...       ...       ...     ...
# 540              no  3000      yes  ...        no   1820000       1
# 541              no  2400       no  ...        no   1767150       1
# 542              no  3620       no  ...        no   1750000       1
# 543              no  2910       no  ...        no   1750000       1
# 544              no  3850       no  ...        no   1750000       2
#
# [545 rows x 13 columns]

# %%
df.sort_values('price',ascending=False)
# Out:
#         price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0    13300000  7420         4  ...        2       yes        furnished
# 2    12250000  9960         3  ...        2       yes   semi-furnished
# 1    12250000  8960         4  ...        3        no        furnished
# 3    12215000  7500         4  ...        3       yes        furnished
# 4    11410000  7420         4  ...        2        no        furnished
# ..        ...   ...       ...  ...      ...       ...              ...
# 540   1820000  3000         2  ...        2        no      unfurnished
# 541   1767150  2400         3  ...        0        no   semi-furnished
# 542   1750000  3620         2  ...        0        no      unfurnished
# 543   1750000  2910         3  ...        0        no        furnished
# 544   1750000  3850         3  ...        0        no      unfurnished
#
# [545 rows x 13 columns]

# %%
df['stories']
# Out:
# 0      3
# 1      4
# 2      2
# 3      2
# 4      2
#       ..
# 540    1
# 541    1
# 542    1
# 543    1
# 544    2
# Name: stories, Length: 545, dtype: int64

# %%
df2=df[0:3]

# %%
df2
# Out:
#       price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0  13300000  7420         4  ...        2       yes        furnished
# 1  12250000  8960         4  ...        3        no        furnished
# 2  12250000  9960         3  ...        2       yes   semi-furnished
#
# [3 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind='scatter',x='price',y='area',color='red')
plt.show()

# %%
df.plot(kind='bar',x='bedrooms',y='price')

# %%
ax = plt.gca()

df.plot(kind='line',x='price',y='bedrooms',ax=ax)
df.plot(kind='line',x='price',y='bathrooms', color='red', ax=ax)

plt.show()

# %%
df.corr()['price']
# Out:
# price        1.000000
# area         0.535997
# bedrooms     0.366494
# bathrooms    0.517545
# stories      0.420712
# parking      0.384394
# Name: price, dtype: float64

# %%
df.groupby('bedrooms')['price'].nunique().plot(kind='bar')
plt.show()

# %%
df.groupby('bathrooms')['price'].nunique().plot(kind='bar')
plt.show()

# %%
df.groupby('guestroom')['price'].nunique().plot(kind='bar')
plt.show()

# %%
df.assign(dummy = 1).groupby(
 ['dummy','bathrooms']
).size().to_frame().unstack().plot(kind='bar',stacked=True,legend=False)

plt.title('House distribution wrt bathrooms')

# other it'll show up as 'dummy' 
plt.xlabel('bathrooms')

# disable ticks in the x axis
plt.xticks([])

# fix the legend
current_handles, _ = plt.gca().get_legend_handles_labels()
reversed_handles = reversed(current_handles)

labels = reversed(df['bathrooms'].unique())

plt.legend(reversed_handles,labels,loc='lower right')
plt.show()
